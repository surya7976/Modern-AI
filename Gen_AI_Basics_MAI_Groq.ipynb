# %% [markdown]
# ### Basic Setup

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.1.2-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.1.2

# %%
import IPython
import os
from google.colab import userdata
# import google.genai as genai
from groq import Groq

# client=genai.Client(api_key=userdata.get('gemini_key'))
groq_client = Groq(api_key=userdata.get('groq_key'))

# from here nothing will change when you use VS code
def Generate_Content(prompt):
   # response = client.models.generate_content(
   #    model="gemini-2.5-flash-lite",
   #    contents=prompt
   # )
   response = groq_client.chat.completions.create(
       messages=[
           {
               "role": "user",
               "content": prompt,
           }
       ],
       model="llama-3.3-70b-versatile",
   )
   return response.choices[0].message.content

# %%
prompt = f"""
Write a program to find out if an year is a leap year or not.
"""

response = Generate_Content(prompt)
print(response)

f=open('response.txt','w')
f.write(response)
f.close()
# Out:
# **Leap Year Checker Program**
# ================================
#
# Below is a Python program that checks whether a given year is a leap year or not.
#
# ```python
# def is_leap_year(year: int) -> bool:
#     """
#     Checks if a year is a leap year.
#
#     A year is a leap year if it is perfectly divisible by 4 except for end-of-century years which must be divisible by 400.
#     This means that the year 2000 was a leap year, although 1900 was not.
#
#     Args:
#         year (int): The year to check.
#
#     Returns:
#         bool: True if the year is a leap year, False otherwise.
#     """
#     return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)
#
#
# def main():
#     year = int(input("Enter a year: "))
#     if is_leap_year(year):
#         print(f"{year} is a leap year.")
#     else:
#         print(f"{year} is not a leap year.")
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# **How to Use:**
# 1. Run the program.
# 2. When prompted, enter a year.
# 3. The program will tell you whether the year is a leap year or not.
#
# **Explanation:**
# * The `is_leap_year` function takes a year as input and returns `True` if it's a leap year and `False` otherwise.
# * A year is a leap year if it's divisible by 4, except for years that are divisible by 100 but not by 400.
# * The `main` function gets a year from the user, checks if it's a leap year, and prints the result.

# %%
# Understanding Strong and Weak patterns

prompt = "Mary has a "

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# It looks like you started to say something about Mary, but it got cut off. Could you please complete your sentence or provide more context about Mary? I'd be happy to help with whatever you're trying to ask or discuss.

# %% [markdown]
# ### Tasks accomplished using Prompt engineering

# %% [markdown]
# **Text Summarization**

# %%
prompt = """Antibiotics are a type of medication used to treat bacterial infections.
They work by either killing the bacteria or preventing them from reproducing,
allowing the body's immune system to fight off the infection. Antibiotics are usually
taken orally in the form of pills, capsules, or liquid solutions, or sometimes
administered intravenously. They are not effective against viral infections, and
using them inappropriately can lead to antibiotic resistance.

Explain the above in one sentence:"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Antibiotics are medications used to treat bacterial infections by killing or preventing the reproduction of bacteria, but they are ineffective against viral infections and can lead to resistance if used inappropriately.

# %% [markdown]
# **Question Answering**

# %%
prompt = """Answer the question based on the context below. Keep the answer short and concise.
Respond "Unsure about answer" if not sure about the answer.

Context: Teplizumab traces its roots to a New Jersey drug company called Ortho Pharmaceutical.
There, scientists generated an early version of the antibody, dubbed OKT3. Originally sourced
from mice, the molecule was able to bind to the surface of T cells and limit their cell-killing
potential. In 1986, it was approved to help prevent organ rejection after kidney transplants,
making it the first therapeutic antibody allowed for human use.

Answer all questions below in Json format

Question1: What was OKT3 originally sourced from?

Answer1:

Question2: Where was Teplizumab traced from?

Answer2:"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# ```json
# {
#   "Answer1": "Mice",
#   "Answer2": "Ortho Pharmaceutical in New Jersey"
# }
# ```

# %% [markdown]
# **Text Classification**

# %%
prompt = """Classify the text into neutral, negative, sarcastic or positive.

Text: I think the food was so good that could not eat.

Sentiment:"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Sentiment: Sarcasm is not strongly indicated, but the statement seems to be illogical. Given that, it could be interpreted as a humorous or ironic take, but since the speaker is stating the food 'was so good', the statement could be considered as 'Sarcasm' but in a mild sense, however the more accurate description would be that the sentence is 'illogical', 'nonsensical', or an example of 'paradoxical statement'. If a choice must be made, 'Sarcastic' seems to fit, as that would be the most common interpretation of this sentence, implying that the food was not that great, and the speaker is being facetious.
#
# So, considering the available options:
# Sentiment: Sarcastic.

# %% [markdown]
# **Reasoning**

# %%
prompt = """The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.

Solve by breaking the problem into steps. First, identify the odd numbers, add them,
and indicate whether the result is odd or even."""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Here's how to solve the problem step-by-step:
#
# **Step 1: Identify the odd numbers.**
#
# An odd number is a whole number that cannot be divided exactly by 2. Let's look at the group: 15, 32, 5, 13, 82, 7, 1.
#
# *   15 is odd (15 / 2 = 7 with a remainder)
# *   32 is even (32 / 2 = 16 with no remainder)
# *   5 is odd (5 / 2 = 2 with a remainder)
# *   13 is odd (13 / 2 = 6 with a remainder)
# *   82 is even (82 / 2 = 41 with no remainder)
# *   7 is odd (7 / 2 = 3 with a remainder)
# *   1 is odd (1 / 2 = 0 with a remainder)
#
# The odd numbers in the group are: **15, 5, 13, 7, 1**.
#
# **Step 2: Add the identified odd numbers.**
#
# 15 + 5 + 13 + 7 + 1 = 41
#
# **Step 3: Indicate whether the result is odd or even.**
#
# The sum of the odd numbers is 41.
# 41 is an **odd** number.

# %% [markdown]
# **Information extraction**

# %%
prompt = """Your task is to extract model names from machine learning
        paper abstracts. Your response is an array of the model names in the format
        [\\\"model_name\\\"]. If you don't find model names in the abstract or you are
        not sure, return [\\\"NA\\\"]\n\nAbstract: Large Language Models (LLMs),
        such as ChatGPT and GPT-4, have revolutionized natural language processing
        research and demonstrated potential in Artificial General Intelligence (AGI).
        However, the expensive training and deployment of LLMs present challenges
        to transparent and open academic research. To address these issues,
        this project open-sources the Chinese LLaMA and Alpaca…"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# ["ChatGPT", "GPT-4", "LLaMA", "Alpaca"]

# %% [markdown]
# **Generating Data**

# %%
prompt = """Produce 10 exemplars for sentiment analysis on movies.
Examples are categorized as either positive or negative.
Produce 2 negative examples and 8 positive examples. Use this format for the examples:
Q: <sentence>
A: <sentiment>"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Q: The movie was a masterpiece, with stunning visuals and a compelling storyline that left me on the edge of my seat.
# A: Positive
#
# Q: I didn't enjoy the film at all, the plot was dull and the characters were underdeveloped.
# A: Negative
#
# Q: The actor's performance in the movie was outstanding, bringing depth and emotion to the character.
# A: Positive
#
# Q: The special effects in the film were breathtaking, making it a truly immersive experience.
# A: Positive
#
# Q: The movie's themes of love and sacrifice resonated deeply with me, making it a memorable watch.
# A: Positive
#
# Q: The cinematography in the film was stunning, capturing the beauty of the landscape perfectly.
# A: Positive
#
# Q: The movie's pacing was well-balanced, keeping me engaged from start to finish.
# A: Positive
#
# Q: I was thoroughly disappointed with the movie, it failed to deliver on its promises.
# A: Negative
#
# Q: The film's soundtrack was incredible, complementing the mood and tone of each scene perfectly.
# A: Positive
#
# Q: The movie's ending was satisfying, tying up loose ends and leaving me feeling fulfilled.
# A: Positive

# %% [markdown]
# ### Prompting Techiques

# %% [markdown]
# **Few-Shot Prompts**

# %%
prompt = """
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: The answer is True.

The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: The answer is False.

The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.
A:"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# The answer is True.

# %% [markdown]
# **Chain-of-Thought (CoT) Prompting**

# %%
prompt = """I went to the market and bought 10 apples.
I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1.
How many apples did I remain with?

Let's think step by step."""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# To find out how many apples you have left, let's break it down step by step:
#
# 1. You initially bought 10 apples.
# 2. You gave away 2 apples to the neighbor and 2 apples to the repairman. So, in total, you gave away 2 + 2 = 4 apples.
# 3. After giving away 4 apples, you had 10 - 4 = 6 apples left.
# 4. You then bought 5 more apples, so now you have 6 + 5 = 11 apples.
# 5. Finally, you ate 1 apple, leaving you with 11 - 1 = 10 apples.
#
# So, after all these transactions, you remained with 10 apples.

# %% [markdown]
# **Chaining Prompts**

# %%
question="""Is lg mobile available for $150?"""
prompt = f""" Follow the below three steps to respond to question from customer
which is delimited with triple backticks?'''{question}'''
Use the following 3 steps and compose a concise answer:

Step 1: If the user is asking about any of the products below move ahead.
Otherwise proceed to step 3.
1. Product: Apple iphone;   Price: $ 200
2. Product: Samsung TV;   Price: $ 100
3. Product: Sony Hometheater;   Price: $ 150
Step 2: If the message contains products
listed above, validate the assumption of user and inform if it is wrong
Step 3: If the message contains products listed above, tell the user that
product will be shipped 3 days after order.Otherwise mention that product
doesn't exist currently."""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# The product mentioned is LG mobile, which is not in our listed products. Since it's not among the listed products (Apple iphone, Samsung TV, Sony Hometheater), the LG mobile does not exist currently in our catalog.

# %% [markdown]
# ### Evaluation

# %% [markdown]
# **Use case 1** - Personalize Basic algebra lesson (30 mins) based upon various parameters like mother tongue, age, IQ level, school grade, special needs and areas to be used for practical examples, Use appropriate examples as required

# %%
prompt = f"""
Create a basic Algebra lesson in english in 4 paragraphs.  This is for a
Grade 6 student with average IQ level.  Since English is his second language
use simple english.  Use good examples for all concepts covered.
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Welcome to Algebra. Algebra is a way of solving puzzles with numbers and letters. It's like a secret code. We use letters to represent unknown numbers, and we use numbers and symbols to solve for the unknown. Let's start with a simple example. Imagine you have 3 groups of 4 pencils. How many pencils do you have in total? We can use a simple equation to solve this problem. The equation is: 3 x 4 = ?. The answer is 12. In Algebra, we would write this as 3x = 12, where x is the number of pencils in each group.
#
# Now, let's learn about variables. A variable is a letter that represents a number. We can use any letter, but we usually use x, y, or z. For example, let's say you have 5 more pencils than your friend. If your friend has x pencils, then you have x + 5 pencils. We can use this equation to solve for x. Let's say you have 10 pencils. Then, we can set up the equation: x + 5 = 10. To solve for x, we need to get x alone on one side of the equation. We can do this by subtracting 5 from both sides of the equation. This gives us x = 5. So, your friend has 5 pencils.
#
# Another important concept in Algebra is balancing equations. An equation is like a seesaw. Whatever we do to one side of the equation, we must do to the other side. For example, let's say we have the equation: 2x = 6. If we divide both sides of the equation by 2, then we get x = 3. This is because dividing by 2 is like moving the 2 to the other side of the equation. It's like balancing the seesaw. We can also add or subtract the same number to both sides of the equation. For example, if we have the equation: x + 2 = 7, we can subtract 2 from both sides to get x = 5.
#
# Let's practice solving some simple equations. Remember to always balance the equation and get the variable alone on one side. For example, let's say we have the equation: x - 3 = 2. To solve for x, we need to add 3 to both sides of the equation. This gives us x = 5. We can check our answer by plugging it back into the original equation. If it's true, then we have the correct answer. For example, if we plug x = 5 into the equation x - 3 = 2, we get 5 - 3 = 2, which is true. So, we know that x = 5 is the correct answer. Keep practicing, and soon you'll be a master of Algebra.

# %%
Eval_answer= f"""
Behave like an Algerba expert and evaluate the lesson,
which is delimited with triple backticks?
'''{response}'''
Rank the lesson on the below parameters from 1 to 10, poor to excellent.
1. Coverage of the concept
2. Ease of understanding for a grade 6 student
3. Quality of the examples used
4. Ease of understanding for a student of average IQ
"""

response = Generate_Content(Eval_answer)
IPython.display.Markdown(response)
# Out:
# As an Algebra expert, I will evaluate the lesson based on the provided parameters. Here are my rankings:
#
# 1. **Coverage of the concept: 8**
# The lesson covers the basic concepts of Algebra, including variables, simple equations, and balancing equations. However, it only scratches the surface of these topics and does not delve deeper into more complex concepts. The lesson provides a good introduction to Algebra, but it may not be comprehensive enough for a thorough understanding of the subject.
#
# 2. **Ease of understanding for a grade 6 student: 7**
# The lesson uses simple language and relatable examples, which makes it accessible to grade 6 students. However, some of the concepts, such as balancing equations, may still be challenging for some students to grasp. The lesson could benefit from more visual aids, diagrams, or real-world examples to help students understand the abstract concepts.
#
# 3. **Quality of the examples used: 9**
# The examples used in the lesson are clear, concise, and relevant to the concepts being taught. The use of everyday objects, such as pencils, makes the examples more relatable and easier to understand. The lesson also provides a good mix of simple and slightly more complex examples to help students build their problem-solving skills.
#
# 4. **Ease of understanding for a student of average IQ: 8**
# The lesson is well-structured and easy to follow, making it accessible to students of average IQ. The language used is simple, and the concepts are explained in a logical and step-by-step manner. However, some students may still struggle with the abstract nature of Algebra, and additional support or practice may be needed to reinforce their understanding.
#
# Overall, the lesson provides a good introduction to Algebra and covers the basic concepts in a clear and concise manner. With some additional examples, visual aids, and practice problems, the lesson could be even more effective in helping students of all skill levels understand and master the concepts of Algebra.

# %% [markdown]
# **Use case 2**- Take a pre-written programming assignment in any programming language and list out the flaws in the logic, potential bugs and write a better program improving it.

# %%
f=open('Sample program.txt','r')
fileContent = f.read()

prompt = f"""
Is the program code written in '''{fileContent}'''
efficient? are test cases there? what are the potential bugs?
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)

# %%
Eval_content= f"""
There was a party

Rank it on the below parameters from 1 to 5, low to high.
1. Violence
2. Harassment
3. Gender bias
"""

response = Generate_Content(Eval_content)
IPython.display.Markdown(response)
# Out:
# Based on the information provided, "There was a party", I would rank it as follows:
#
# 1. Violence: 1 (There is no indication of any violence at the party.)
# 2. Harassment: 1 (There is no indication of any harassment at the party.)
# 3. Gender bias: 1 (There is no indication of any gender bias at the party.)
#
# Please note that these rankings are based on a lack of information, and without further context, it's impossible to make a more informed assessment.

# %% [markdown]
# **Identify Hallucination**

# %%
prompt ="""How is political governance handed in tribal hamlets near western ghats?

        Can the answer generated above be incorrect and product of hallucination?
        Rank it on a scale of 1 to 10 for hallucination 1 being lowest"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# The question of how political governance is handled in tribal hamlets near the Western Ghats can be complex and varied, as these communities often have their own traditional systems of governance and may interact with external governance structures in unique ways.
#
# In general, tribal hamlets near the Western Ghats may have their own traditional councils or decision-making bodies, such as the "Gram Sabha" or village council, which are responsible for managing local affairs and making decisions about community resources. These councils may be composed of elder members of the community or other respected individuals.
#
# In addition to these traditional systems, the Indian government has also established various mechanisms for governing and supporting tribal communities, such as the Tribal Welfare Department and the Integrated Tribal Development Programme (ITDP). These programs aim to provide basic services such as healthcare, education, and infrastructure, as well as to promote economic development and social welfare.
#
# However, the effectiveness of these governance systems can vary widely depending on factors such as the level of funding, the capacity of local institutions, and the degree of community participation. In some cases, tribal communities may also face challenges related to land rights, displacement, and environmental degradation, which can impact their governance and well-being.
#
# Given the complexity and variability of governance systems in tribal hamlets near the Western Ghats, I would rate the likelihood of an incorrect answer due to hallucination as a 6 out of 10. While it is possible to provide a general overview of governance systems in these communities, there is a risk of oversimplification or inaccuracies due to the diversity of experiences and contexts. To provide a more accurate answer, it would be necessary to consult specific research or data on governance systems in these communities.
#
# Here are some reasons why the answer could be incorrect:
#
# 1. **Lack of specific data**: Without access to specific data or research on governance systems in tribal hamlets near the Western Ghats, it is difficult to provide an accurate answer.
# 2. **Variability in governance systems**: Governance systems can vary widely across different communities and regions, making it challenging to provide a general answer that applies to all contexts.
# 3. **Limited understanding of community dynamics**: Without a deep understanding of the social, cultural, and economic dynamics of tribal communities, it is possible to misinterpret or oversimplify the ways in which governance systems function.
#
# To minimize the risk of hallucination, it is essential to rely on credible sources of information, such as academic research, government reports, or community-based organizations, and to approach the question with a nuanced and contextual understanding of the complexities involved.

# %% [markdown]
# ### Prompt Patterns

# %% [markdown]
# **The Persona pattern**

# %%
# Set behaviour

prompt = """Act as a sceptic that is well versed in computer science.
whatever i tell you, privide a short and sceptical answer.

AI doesn't really do anything useful or great.
"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Oh, please. "Useful or great"? Define "useful." Is automating tedious tasks "useful"? Is generating repetitive, predictable content "great"? We're talking about sophisticated pattern matching and statistical prediction, not genuine intelligence or creativity. It's a glorified calculator with an impressive vocabulary, built on mountains of scraped data. Don't confuse correlation with causation, or a well-trained algorithm with sentience.

# %% [markdown]
# **Question refienment pattern**

# %%
# Set behaviour
prompt = """whenever I ask a question,
suggest few better question and ask me if I would like to use it instead.

How to reduce power consumption of a laptop?
"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# That's a great question! Reducing laptop power consumption is a common goal.
#
# Here are a few alternative ways to phrase your question that might elicit even more specific or targeted advice:
#
# 1.  **"What are the most effective software settings and hardware optimizations to significantly decrease my laptop's battery drain?"** (This focuses on both software and hardware and emphasizes "significant" impact.)
# 2.  **"Can you provide a step-by-step guide on how to extend my laptop's battery life through everyday usage habits and configuration changes?"** (This is more action-oriented and focuses on practical "everyday" tips.)
# 3.  **"What are the key power-saving features I should be aware of and utilize on my laptop to maximize battery performance?"** (This highlights understanding and using built-in features.)
#
# Would you like to rephrase your question using one of these suggestions, or shall I answer your original question: "How to reduce power consumption of a laptop?"

# %% [markdown]
# **Audience persona pattern**

# %%
# Set behaviour
prompt = """Explain gravity to me.
Assume that I am a novice in scientific things
"""

response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Imagine you have a ball. When you let go of that ball, what happens? It falls to the ground, right? This is because of something called **gravity**.
#
# **Gravity is like an invisible pulling force.** Everything that has "stuff" in it – what scientists call "mass" – has this pulling force. The more "stuff" something has, the stronger its pull.
#
# **Think of it like this:**
#
# *   **Earth has a LOT of "stuff" (mass).** It's huge! So, Earth has a very strong gravity. This is why when you jump, you always come back down. Earth's gravity is pulling you towards it.
# *   **You have "stuff" too, but much, much less than Earth.** So, you also have gravity, but it's incredibly weak. It's so weak that you can't really feel it pulling on other things around you.
# *   **The Sun has even MORE "stuff" than Earth.** It's gigantic! So, the Sun's gravity is even stronger. This is why Earth and all the other planets in our solar system don't just float away. The Sun's gravity is pulling them towards it, keeping them in orbit, like a leash.
#
# **Here are some key things to remember about gravity:**
#
# *   **It's a pull, not a push.** It always tries to bring things closer together.
# *   **It depends on "stuff" (mass).** More mass means stronger gravity.
# *   **It depends on distance.** The farther apart two things are, the weaker the pull between them. Think of it like a magnet – the closer you get, the stronger the pull.
# *   **It's everywhere!** Even the tiniest speck of dust has gravity, but it's so small you'll never notice it.
#
# **So, in simple terms, gravity is what keeps your feet on the ground, what makes things fall when you drop them, and what keeps the Moon orbiting the Earth, and the Earth orbiting the Sun!**
#
# It's a fundamental force that shapes our entire universe. It's the reason why planets form, why stars shine, and why galaxies stay together.
#
# Does that make a bit of sense? Feel free to ask if any part is confusing!

# %% [markdown]
# **Cognitive Verifier pattern**

# %%
# Set behaviour

prompt = """When you are asked a question, follow these rules
Generate 3 additional questions that would help more accurately answer the question

What crop is ideal to be sown?
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# To determine the ideal crop to be sown, I'd like to ask the following questions:
#
# 1. **What is the climate and geographic location** where the crop will be sown, as different crops thrive in different conditions?
# 2. **What is the purpose of sowing the crop**, is it for food, fodder, or other uses, as this can influence the choice of crop?
# 3. **What is the available soil type and quality**, as certain crops are more suitable for specific soil conditions, such as acidity, moisture levels, or nutrient content?

# %%
prompt = """
1. Climate is arid
2. Soil type is black cotton
3. Market demand is high

What crop is ideal to be sown?
"""
# Combine the answers to the individual questions to produce the final answer to the overall question
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Based on the given conditions:
#
# 1. Climate is arid (low rainfall)
# 2. Soil type is black cotton (retains moisture, fertile, and suitable for water-intensive crops)
# 3. Market demand is high
#
# Considering these factors, the ideal crop to be sown is Cotton. Cotton is a suitable crop for arid climates with moderate rainfall, and black cotton soil is particularly well-suited for cotton cultivation. Additionally, cotton is a high-demand crop, making it a profitable choice.

# %% [markdown]
# **Flipped Interaction pattern**

# %%
# Set behaviour

prompt = """Ask me 3 questions about fitness goals so that you have enough
information to suggest a strength training regime for me.
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Okay, I'm ready to craft a strength training regime tailored for you! To do that, I need a little more information. Here are my three questions:
#
# 1.  **What is your primary motivation for wanting to strength train?** (e.g., build muscle, lose fat, improve general health and energy, increase strength for a specific sport or activity, improve bone density, rehabilitation from an injury, etc.)
# 2.  **How much time can you realistically commit to strength training per week, and what days/times work best for you?** (Be specific about the duration of each session as well.)
# 3.  **What is your current experience level with strength training?** (e.g., complete beginner with no experience, beginner who has tried a few things, intermediate with consistent training for a few months to a year, advanced with years of consistent and structured training.)

# %%
prompt = """
1. Strength
2. Twice a week
3. Muscles

Show me the strength traing regime
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Here's a strength training regime based on your keywords: "Strength," "Twice a week," and "Muscles." This is a beginner-friendly full-body program designed to hit major muscle groups effectively with two sessions per week.
#
# **Philosophy:**
#
# *   **Full Body:** Each workout targets major muscle groups to maximize efficiency and stimulate overall muscle growth.
# *   **Progressive Overload:** The key to strength gains is gradually increasing the challenge over time. This can be done by increasing weight, reps, sets, or decreasing rest time.
# *   **Compound Movements:** We'll focus on exercises that work multiple muscle groups simultaneously, as these are the most effective for building overall strength and mass.
# *   **Proper Form Over Everything:** Always prioritize correct technique to prevent injuries and ensure you're effectively targeting the intended muscles.
#
# **The Program: Twice a Week Full Body Strength**
#
# **Schedule:**
#
# *   Choose two non-consecutive days for your workouts (e.g., Monday & Thursday, Tuesday & Friday).
# *   Allow at least one rest day between workouts.
#
# **Workout Structure (for each session):**
#
# 1.  **Warm-up (5-10 minutes):**
#     *   **Light Cardio:** 5 minutes of brisk walking, jogging, cycling, or jumping jacks to get your blood flowing.
#     *   **Dynamic Stretching:** 5-10 minutes of movements like arm circles, leg swings, torso twists, hip circles, and bodyweight squats to prepare your joints and muscles.
#
# 2.  **Strength Training (30-45 minutes):**
#     *   Perform the exercises in the order listed.
#     *   **Sets:** 3 sets per exercise.
#     *   **Reps:** Aim for the lower end of the rep range initially and focus on controlled movements. As you get stronger, you can increase reps or weight.
#     *   **Rest:** 60-90 seconds between sets.
#     *   **Weight Selection:** Choose a weight that challenges you to complete the target number of reps with good form. The last 1-2 reps should be difficult, but not impossible.
#
# 3.  **Cool-down (5-10 minutes):**
#     *   **Static Stretching:** Hold stretches for major muscle groups for 30 seconds. Focus on areas you worked during the session. Examples: hamstring stretch, quad stretch, chest stretch, triceps stretch, shoulder stretch.
#
# ---
#
# **The Exercises:**
#
# **Day 1 & Day 2 (Same Workout)**
#
# This program is designed to be done on both of your training days.
#
# *   **Lower Body (Compound Focus):**
#     *   **Squats (Barbell Back Squat or Goblet Squat):**
#         *   **Target Muscles:** Quadriceps, glutes, hamstrings, core.
#         *   **Sets:** 3
#         *   **Reps:** 8-12
#         *   **Focus:** Keep your chest up, back straight, and drive through your heels. Go as deep as your flexibility allows while maintaining good form. If you're new, start with Goblet Squats using a dumbbell or kettlebell.
#
#     *   **Romanian Deadlifts (RDLs) (Barbell or Dumbbell):**
#         *   **Target Muscles:** Hamstrings, glutes, lower back, forearms.
#         *   **Sets:** 3
#         *   **Reps:** 8-12
#         *   **Focus:** Hinge at your hips, keeping your back straight and a slight bend in your knees. Feel the stretch in your hamstrings. Lower the weight until you feel a good stretch, then return to the starting position by squeezing your glutes.
#
# *   **Upper Body (Push Focus):**
#     *   **Bench Press (Barbell or Dumbbell):**
#         *   **Target Muscles:** Chest, shoulders (anterior deltoids), triceps.
#         *   **Sets:** 3
#         *   **Reps:** 8-12
#         *   **Focus:** Lower the weight to your mid-chest, keeping your elbows at about a 45-degree angle to your body. Push the weight back up powerfully.
#
#     *   **Overhead Press (Barbell or Dumbbell):**
#         *   **Target Muscles:** Shoulders (deltoids), triceps, upper chest.
#         *   **Sets:** 3
#         *   **Reps:** 8-12
#         *   **Focus:** Press the weight directly overhead, keeping your core tight and avoiding excessive back arching. Control the descent.
#
# *   **Upper Body (Pull Focus):**
#     *   **Barbell Rows or Dumbbell Rows:**
#         *   **Target Muscles:** Back (lats, rhomboids, traps), biceps, forearms.
#         *   **Sets:** 3
#         *   **Reps:** 8-12
#         *   **Focus:** Hinge at your hips, keeping your back straight. Pull the weight towards your lower chest/upper abdomen, squeezing your shoulder blades together at the top. Control the negative (lowering) motion.
#
#     *   **Pull-ups or Lat Pulldowns:**
#         *   **Target Muscles:** Back (lats), biceps.
#         *   **Sets:** 3
#         *   **Reps:** As many as possible (AMRAP) for pull-ups, or 8-12 for lat pulldowns.
#         *   **Focus:** If you can't do pull-ups, use an assisted pull-up machine or perform lat pulldowns. Aim for a full range of motion, pulling your chest towards the bar/handle.
#
# *   **Core:**
#     *   **Plank:**
#         *   **Target Muscles:** Core (abs, obliques, lower back).
#         *   **Sets:** 3
#         *   **Hold:** 30-60 seconds (or as long as you can maintain good form).
#         *   **Focus:** Keep your body in a straight line from head to heels, engaging your core and glutes. Avoid sagging your hips or raising your butt too high.
#
# ---
#
# **Progression (How to Get Stronger):**
#
# *   **Week 1-4 (Foundation):** Focus on learning the form for each exercise. Use lighter weights that allow you to complete all reps with perfect technique.
# *   **Week 5 onwards (Progressive Overload):**
#     *   **Increase Weight:** Once you can comfortably complete the higher end of the rep range (e.g., 12 reps) for all sets of an exercise with good form, increase the weight slightly (e.g., by 2.5-5 lbs for dumbbells, 5-10 lbs for barbells) on your next workout.
#     *   **Increase Reps:** If you can't increase weight, aim to do one or two more reps on each set.
#     *   **Increase Sets:** Occasionally, you can add an extra set to an exercise.
#     *   **Decrease Rest:** Slightly reduce rest times between sets.
#
# **Important Considerations:**
#
# *   **Listen to Your Body:** If you feel pain (not muscle fatigue), stop the exercise.
# *   **Nutrition:** Adequate protein intake is crucial for muscle repair and growth. Ensure you're eating a balanced diet.
# *   **Sleep:** Muscles grow and repair during rest. Aim for 7-9 hours of quality sleep per night.
# *   **Consistency:** The most important factor for seeing results is sticking to your training schedule.
# *   **Form Videos:** Watch videos of each exercise to ensure you understand proper technique. There are many excellent resources online.
# *   **Progression:** Don't be afraid to increase the weight as you get stronger. This is how you continue to build muscle and strength.
# *   **Warm-up is Non-Negotiable:** Skipping the warm-up increases your risk of injury.
#
# This program provides a solid foundation for building strength and muscle with just two workouts a week. As you progress, you can explore variations or more advanced programs, but this is an excellent starting point!

# %% [markdown]
# **Recipe pattern**

# %%
# Set behaviour
prompt = """I would like to  purchase a house. I know that I need to perform
steps make an offer and close on the house. Provide a complete sequence of
steps for me. Fill in any missing steps.
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Buying a house is a significant and exciting process! You're right, making an offer and closing are key milestones, but there are several important steps that happen before and between them. Here's a complete sequence of steps to guide you through purchasing a house:
#
# **Phase 1: Preparation and Pre-Approval**
#
# 1.  **Assess Your Financial Situation:**
#     *   **Calculate your budget:** Determine how much you can realistically afford for a down payment, closing costs, and monthly mortgage payments (including principal, interest, taxes, and insurance - PITI).
#     *   **Check your credit score:** A good credit score is crucial for getting approved for a mortgage and securing a favorable interest rate. Obtain your credit reports from the major bureaus (Equifax, Experian, TransUnion) and address any errors or issues.
#     *   **Save for a down payment and closing costs:** This includes not only the down payment percentage but also funds for appraisal fees, inspection fees, title insurance, legal fees, etc.
#
# 2.  **Get Pre-Approved for a Mortgage:**
#     *   **Shop around for lenders:** Contact multiple banks, credit unions, and mortgage brokers to compare interest rates, fees, and loan programs.
#     *   **Submit a mortgage application:** Provide financial documentation (pay stubs, tax returns, bank statements, W-2s, etc.) to your chosen lender.
#     *   **Receive a pre-approval letter:** This letter states the maximum loan amount you qualify for, giving you a clear price range and making you a more serious buyer in the eyes of sellers.
#
# 3.  **Find a Real Estate Agent (Optional, but Highly Recommended):**
#     *   **Research and interview agents:** Look for agents with experience in your desired neighborhoods, a good track record, and strong communication skills.
#     *   **Sign a buyer's agency agreement:** This formalizes your relationship with the agent and outlines their responsibilities and your commitments.
#
# **Phase 2: House Hunting and Making an Offer**
#
# 4.  **Define Your Needs and Wants:**
#     *   **Location:** Consider neighborhoods, school districts, commute times, amenities, and future development plans.
#     *   **Type of home:** Single-family, townhouse, condo, etc.
#     *   **Size and layout:** Number of bedrooms and bathrooms, square footage, desired room configurations.
#     *   **Features:** Yard, garage, specific architectural style, modern updates, etc.
#     *   **Condition:** Move-in ready or willing to do renovations.
#
# 5.  **Begin House Searching:**
#     *   **Work with your agent:** They will provide listings, schedule showings, and offer insights.
#     *   **Attend open houses and schedule private showings:** Get a feel for different properties and neighborhoods.
#     *   **Utilize online real estate platforms:** Websites like Zillow, Realtor.com, Redfin, etc., can be helpful for research.
#
# 6.  **Make an Offer:**
#     *   **Work with your agent to determine an offer price:** This involves analyzing comparable sales (comps) in the area.
#     *   **Prepare the purchase agreement (offer contract):** This legally binding document includes:
#         *   Offer price
#         *   Financing terms (how you'll pay, including mortgage details)
#         *   Contingencies (conditions that must be met for the sale to proceed, such as financing, inspection, appraisal, and sale of your current home if applicable)
#         *   Earnest money deposit (a good faith deposit to show you're serious)
#         *   Proposed closing date
#         *   Inclusions and exclusions (what stays with the house, like appliances)
#
# 7.  **Negotiate the Offer:**
#     *   **Seller accepts, rejects, or counter-offers:** Be prepared for negotiations on price, terms, and contingencies.
#     *   **Reach an agreement and sign the purchase agreement:** Once both parties agree and sign, you have a ratified contract.
#
# **Phase 3: Due Diligence and Loan Processing**
#
# 8.  **Deposit Earnest Money:**
#     *   You'll typically deposit your earnest money with an escrow company or your real estate agent's brokerage shortly after the offer is accepted.
#
# 9.  **Schedule and Conduct Home Inspections:**
#     *   **Hire a qualified home inspector:** This is a crucial step to identify any potential issues with the property's structure, systems (plumbing, electrical, HVAC), roof, foundation, etc.
#     *   **Attend the inspection:** Ask questions and understand the findings.
#     *   **Review the inspection report:** Based on the report, you may:
#         *   Proceed with the sale as is.
#         *   Request repairs or credits from the seller.
#         *   Walk away from the deal if major issues are uncovered and you cannot reach an agreement with the seller (assuming you have an inspection contingency).
#
# 10. **Finalize Your Mortgage Application and Appraisal:**
#     *   **Submit all required documentation to your lender:** This is an ongoing process as they verify your financial information.
#     *   **Lender orders an appraisal:** This professional assessment determines the fair market value of the home. The lender uses this to ensure the loan amount is not more than the home's value.
#
# 11. **Secure Homeowners Insurance:**
#     *   **Shop for and obtain a homeowners insurance policy:** Your lender will require proof of insurance before closing.
#
# 12. **Conduct a Title Search and Obtain Title Insurance:**
#     *   **Title company researches the property's history:** This ensures there are no liens, claims, or encumbrances on the title.
#     *   **Title insurance protects you and the lender:** It safeguards against future title disputes.
#
# 13. **Review Loan Estimates and Disclosures:**
#     *   **Compare the Loan Estimate (LE) with the Closing Disclosure (CD):** Your lender provides these documents detailing all loan terms, fees, and estimated closing costs. The CD is a final version you'll receive a few days before closing.
#
# **Phase 4: Closing**
#
# 14. **Conduct a Final Walk-Through:**
#     *   **Usually done 24-48 hours before closing:** This is your last chance to ensure the property is in the agreed-upon condition, all agreed-upon repairs have been made, and no new damage has occurred.
#
# 15. **Attend the Closing (Settlement):**
#     *   **Meet with your real estate agent, attorney (if applicable), and the closing agent/title company representative.**
#     *   **Review and sign all closing documents:** This includes the mortgage note, deed of trust, and various disclosures.
#     *   **Bring your certified funds for closing costs and the remaining down payment:** This will be outlined on your Closing Disclosure.
#     *   **Seller signs over the deed to you.**
#
# 16. **Receive the Keys!**
#     *   Once all documents are signed, funds are disbursed, and the deed is recorded, you officially become the homeowner!
#
# This is a comprehensive outline, and the exact order or specifics might vary slightly based on your location and the complexity of the transaction. Always communicate closely with your real estate agent and lender throughout the entire process. Congratulations on your journey to homeownership!

# %% [markdown]
# **Alternative approaches pattern**

# %%
# Set behaviour

prompt = """For anything that I ask you, determine the underlying
problem that I am trying to solve and how I am trying to solve it. List at least
one alternative approach to solve the problem and compare / contrast the approach
with the original approach implied by my request to you.

How can I make my internet work faster?
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Let's break down your request, "How can I make my internet work faster?"
#
# ## Underlying Problem:
#
# The core problem you're trying to solve is **slow internet performance**. This manifests as:
#
# *   **Longer loading times:** Websites, videos, and applications take an excessive amount of time to load or buffer.
# *   **Lag or stuttering:** Online activities like gaming, video conferencing, or streaming are interrupted by delays.
# *   **Low download/upload speeds:** Transferring files takes significantly longer than expected.
# *   **Frustration and inefficiency:** The slow internet is hindering your ability to work, communicate, and enjoy your digital life.
#
# ## How You're Trying to Solve It:
#
# Your request implies you're seeking **practical, actionable steps and information to improve your internet speed**. You're looking for solutions that you can implement yourself or understand the factors contributing to the slowness so you can address them. You're assuming there are methods to directly influence and increase the speed of your internet connection.
#
# ## Alternative Approach:
#
# While your approach is focused on direct speed improvement, an alternative approach would be to **optimize your usage and hardware to maximize the *perceived* speed and efficiency of your current connection.**
#
# This alternative approach focuses on:
#
# *   **Reducing demand:** Minimizing the amount of data being processed simultaneously.
# *   **Improving signal quality:** Ensuring your devices are receiving the best possible signal from your router.
# *   **Streamlining data flow:** Making sure data isn't getting bottlenecked by your devices or network configuration.
#
# ## Comparison and Contrast:
#
# Here's a comparison and contrast between your implied approach (direct speed improvement) and the alternative approach (optimization for perceived speed):
#
# | Feature              | Your Implied Approach (Direct Speed Improvement)                                                                                                | Alternative Approach (Optimization for Perceived Speed)                                                                                                                            |
# | :------------------- | :---------------------------------------------------------------------------------------------------------------------------------------------- | :--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Primary Goal**     | To achieve a higher *measured* internet speed from your ISP (e.g., upgrading plan, troubleshooting hardware for maximum throughput).              | To make your current internet connection *feel* faster and more responsive, even if the raw download/upload speeds don't significantly increase.                                |
# | **Focus Areas**      | ISP plan, modem/router hardware, physical cabling, network congestion at the ISP level.                                                           | Device performance, Wi-Fi signal strength and interference, network configuration (DNS, QoS), reducing background data usage, optimizing individual application settings.             |
# | **Typical Actions**  | Calling ISP to upgrade plan, buying a new modem/router, checking for ISP outages, ensuring wired connections.                                  | Restarting router, moving router, reducing number of connected devices, closing unnecessary apps, updating device drivers, changing Wi-Fi channel, using QoS settings, clearing cache. |
# | **Nature of Solutions** | Often involves expenditure (plan upgrade, new hardware) or direct intervention with your ISP.                                                    | Often involves no or low cost, focusing on user behavior and existing hardware configurations.                                                                                      |
# | **Impact on "Speed"** | Can lead to a tangible increase in raw download/upload speeds.                                                                                  | Improves responsiveness, reduces buffering, makes individual tasks feel faster, and can alleviate perceived slowness even if raw speeds are the same.                                |
# | **Potential Limitations** | Your ISP plan may have a cap on actual speed, even with the best hardware. Upgrades can be expensive.                                        | Cannot overcome fundamental limitations of your ISP's service speed. May not address core issues like outdated hardware or poor ISP infrastructure.                               |
# | **Complementary Nature** | **Highly complementary.** Optimizing your usage can make the most of the speed you *do* have, and a faster plan combined with optimization will yield the best results. | **Highly complementary.** Optimization can mask or mitigate the effects of a slower plan, making it more tolerable.                                                              |
#
# **In summary:**
#
# *   **Your implied approach** aims to address the root cause by increasing the "pipe" size or efficiency of data transfer from your ISP.
# *   **The alternative approach** focuses on making the existing "pipe" more efficient by managing what flows through it and how it's received and processed by your devices.
#
# Both approaches are valid and often work best in tandem. To truly make your internet "work faster," you'd ideally consider elements of both.

# %% [markdown]
# **Outline expansion pattern**

# %%
# Set behaviour

prompt = """Act as an outline expander.
Generate a bullet point outline based on the input that I give you and
then ask me for which bullet point you should expand on.

Type of mammals
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Here is a basic outline based on your input:
#
# *   **Mammals**
#     *   Key Characteristics of Mammals
#     *   Major Groups/Classifications of Mammals
#     *   Examples of Mammals by Group
#     *   Mammalian Adaptations and Diversity
#
# ---
#
# Which of these bullet points would you like me to expand on?

# %%
prompt = """
Marine mammals

Create a new bullet point outline for the above selection.
After I select one of them, explain it
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Here's a bullet point outline for "Marine Mammals," followed by instructions on how I'll explain a chosen topic:
#
# *   **I. Introduction to Marine Mammals**
#     *   A. Definition and Classification
#     *   B. Adaptations for Aquatic Life
#     *   C. Evolutionary History
#
# *   **II. Major Groups of Marine Mammals**
#     *   A. Cetaceans
#         *   1. Whales (Baleen and Toothed)
#         *   2. Dolphins
#         *   3. Porpoises
#     *   B. Pinnipeds
#         *   1. Seals
#         *   2. Sea Lions
#         *   3. Walruses
#     *   C. Sirenians
#         *   1. Manatees
#         *   2. Dugongs
#     *   D. Marine Fissipeds (Briefly)
#         *   1. Sea Otters
#         *   2. Polar Bears
#
# *   **III. Physiology and Adaptations**
#     *   A. Respiration (Breath-holding, Diving)
#     *   B. Thermoregulation (Blubber, Fur)
#     *   C. Sensory Systems (Echolocation, Vision, Hearing)
#     *   D. Locomotion (Flippers, Flukes)
#     *   E. Diet and Foraging
#
# *   **IV. Behavior and Social Structure**
#     *   A. Communication (Vocalizations, Body Language)
#     *   B. Migration Patterns
#     *   C. Social Groups and Alliances
#     *   D. Reproduction and Parental Care
#
# *   **V. Ecology and Habitat**
#     *   A. Marine Ecosystems (Oceans, Coastal Waters, Polar Regions)
#     *   B. Role in Food Webs
#     *   C. Habitat Use and Distribution
#
# *   **VI. Conservation and Threats**
#     *   A. Human Impacts (Pollution, Overfishing, Shipping, Climate Change)
#     *   B. Entanglement and Stranding
#     *   C. Conservation Efforts and Legislation
#     *   D. Importance of Marine Mammal Research
#
# ---
#
# **How to Proceed:**
#
# Please select **one** of the bullet points from the outline above (e.g., "A. Definition and Classification" under "I. Introduction to Marine Mammals," or "A. Cetaceans" under "II. Major Groups of Marine Mammals," or "C. Sensory Systems" under "III. Physiology and Adaptations," etc.).
#
# Once you tell me your selection, I will provide a detailed explanation of that specific topic.

# %%
prompt = """
Dolphins
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# Dolphins are fascinating and intelligent marine mammals that belong to the order Cetacea, a group that also includes whales and porpoises. They are renowned for their playful nature, complex social structures, and remarkable cognitive abilities.
#
# Here's a breakdown of key aspects of dolphins:
#
# **Physical Characteristics:**
#
# *   **Streamlined Bodies:** Built for speed and agility in the water, their bodies are torpedo-shaped.
# *   **Flippers and Flukes:** They have pectoral flippers for steering and stabilization, and a powerful horizontal fluke (tail) for propulsion.
# *   **Dorsal Fin:** Most dolphin species have a dorsal fin on their back, which helps with stability.
# *   **Blowhole:** Located on the top of their head, the blowhole is used for breathing. When they surface, they exhale through the blowhole, creating a characteristic spout.
# *   **Teeth:** Dolphins have cone-shaped teeth that they use to catch slippery prey. They don't chew their food; they swallow it whole.
# *   **Echolocation:** A defining feature of dolphins is their ability to use echolocation. They emit high-frequency clicks and interpret the returning echoes to "see" their surroundings, locate prey, and navigate.
#
# **Behavior and Intelligence:**
#
# *   **Social Animals:** Dolphins are highly social and live in groups called pods. These pods can vary in size from a few individuals to hundreds.
# *   **Complex Communication:** They communicate using a variety of clicks, whistles, and body language. Each dolphin may have a unique "signature whistle" that acts like a name.
# *   **Playfulness:** Dolphins are known for their energetic and playful behavior, often seen leaping out of the water (breaching), riding waves, and interacting with each other.
# *   **Intelligence:** Dolphins are considered one of the most intelligent animal species on Earth. They exhibit problem-solving abilities, self-awareness (they recognize themselves in mirrors), and can learn complex tasks.
# *   **Cooperative Hunting:** Many dolphin species hunt cooperatively, using sophisticated strategies to herd fish or other prey.
#
# **Diet:**
#
# *   Dolphins are carnivores and their diet consists mainly of fish and squid. The specific diet varies depending on the species and their habitat.
#
# **Habitat and Distribution:**
#
# *   Dolphins are found in oceans worldwide, from tropical to temperate waters. Some species also inhabit freshwater rivers.
# *   They are marine mammals, meaning they live in the ocean but breathe air.
#
# **Species Diversity:**
#
# *   There are over 40 recognized species of dolphins, ranging in size from the small Maui dolphin (around 5 feet long) to the larger orcas (killer whales), which are technically the largest dolphin species.
# *   Some well-known species include the Bottlenose Dolphin, Common Dolphin, Spinner Dolphin, and Orca.
#
# **Threats and Conservation:**
#
# Dolphins face various threats, including:
#
# *   **Bycatch:** Accidental entanglement in fishing gear is a major threat.
# *   **Pollution:** Plastic debris, chemical pollutants, and noise pollution can harm dolphins.
# *   **Habitat Degradation:** Loss of coastal habitats due to development and other human activities.
# *   **Climate Change:** Rising ocean temperatures and changes in prey distribution can impact dolphin populations.
# *   **Intentional Killing:** In some parts of the world, dolphins are hunted for food or sport.
#
# Conservation efforts are underway to protect dolphins, including the establishment of marine protected areas, the development of more sustainable fishing practices, and research into dolphin health and behavior.
#
# **Fun Facts:**
#
# *   Dolphins sleep by resting one half of their brain at a time, allowing them to remain conscious enough to breathe and avoid predators.
# *   They are believed to have a strong sense of empathy and can sometimes be seen helping injured or stranded individuals.
# *   Orcas are incredibly skilled hunters and can take down prey as large as other whales.
#
# Dolphins continue to capture our imagination and inspire scientific research due to their intelligence, social complexity, and the mystery of their underwater lives.

# %% [markdown]
# **Semantic filter pattern**

# %%
# Set behaviour
txt="""
Mr. Alex went to paris last Friday..
"""

prompt = f"""
Filter out all personally identifiable information in the text contained in
'''{txt}''' and put ### in its place and output the content
"""
response = Generate_Content(prompt)
IPython.display.Markdown(response)
# Out:
# ### went to ### last ###..
